# %%
# !pip install scalecast
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#   Using cached SCALECAST-0.15.12.tar.gz (680 kB)
#   Preparing metadata (setup.py) ... done
# ...
#   Using cached eli5-0.13.0.tar.gz (216 kB)
#   Preparing metadata (setup.py) ... done
# ...
#   Using cached lightgbm-3.3.3-py3-none-manylinux1_x86_64.whl (2.0 MB)
# ...
#   Using cached openpyxl-3.0.10-py2.py3-none-any.whl (242 kB)
# ...
#   Using cached pandas_datareader-0.10.0-py3-none-any.whl (109 kB)
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 588.3/588.3 MB ? eta 0:00:000:00:0100:05
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 193.6/193.6 MB 879.4 kB/s eta 0:00:0000:0100:03
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.0/47.0 KB 1.1 MB/s eta 0:00:00a 0:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 2.2 MB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.6/124.6 KB 3.7 MB/s eta 0:00:00
# ...
